# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ex1data1.txt", header=None, names=['Population','Profit'])

# %%
plt.scatter(data[['Population']], data[['Profit']])
plt.ylabel('Profit in $10,000s')
plt.xlabel('Population of City in 10,000s')
plt.show()

# %%
data_mat = np.matrix(data)

# %%
Y = data_mat[:,1]

# %%
X = np.ones([97,1])
X = np.append(X, data_mat[:,0], axis=1)
#X
#X = data_mat[:,0]
#X = np.append(X,np.ones([97,1]),axis=1)
#X

# %%
theta = np.zeros((2,1))
theta
# Out:
# array([[0.],
#        [0.]])

# %%
iterations = 1500
alpha = 0.01

# %%
for i in range(iterations):
    cost = (1/(2*97))*(np.square(X*theta - Y)).sum()
    theta[0] = theta[0] - ((alpha/97)*((X*theta - Y).sum()))
    theta[1] = theta[1] - (alpha/97)*(np.multiply((X*theta - Y),(X[:,1])).sum())
    print(cost)
cost = (1/(2*97))*(np.square(X*theta - Y)).sum()
# Out:
# 32.072733877455676
# 6.79372769071752
# 5.934595771472088
# 5.901428122232098
# 5.895503091000776
# 5.8903623325570615
# 5.885236760125835
# 5.880124264360999
# 5.875029148293899
# 5.869952310601328
# 5.864893867445509
# 5.859853785820321
# 5.854832005275342
# 5.849828460498954
# 5.844843085481142
# 5.8398758142793525
# 5.834926581158781
# 5.829995320617496
# 5.825081967390356
# 5.820186456449019
# 5.815308723001257
# 5.810448702490113
# 5.805606330593066
# 5.800781543221174
# 5.79597427651822
# 5.791184466859885
# 5.786412050852887
# 5.781656965334148
# 5.776919147369965
# 5.772198534255168
# 5.767495063512294
# 5.762808672890764
# 5.758139300366048
# 5.75348688413886
# 5.748851362634319
# 5.7442326745011565
# 5.739630758610892
# 5.735045554057023
# 5.730477000154225
# 5.725925036437542
# 5.721389602661593
# 5.716870638799771
# 5.712368085043449
# 5.707881881801186
# 5.7034119696979415
# 5.698958289574288
# 5.694520782485633
# 5.69009938970143
# 5.685694052704408
# ...

# %% [markdown]
# theta = np.linalg.inv((X.transpose()*X))*X.transpose()*Y

# %%
cost = (1/(2*97))*(np.square(X*theta - Y)).sum()

# %%
cost
# Out:
# 4.483112138339371

# %%
theta
# Out:
# array([[-3.63606348],
#        [ 1.16698916]])

# %%
test = np.matrix([1,5.3054])
test*theta
# Out:
# matrix([[2.5552808]])

# %%
plt.scatter(data[['Population']], data[['Profit']])
plt.ylabel('Profit in $10,000s')
plt.xlabel('Population of City in 10,000s')
plt.plot([5.3054,22.203], [2.5552808, 22.2745968], 'k-', color = 'r')

plt.show()
